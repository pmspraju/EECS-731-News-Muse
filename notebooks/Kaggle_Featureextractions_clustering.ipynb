# %% [markdown]
# #### Importing all the required libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import seaborn as sns
from sklearn.cluster import DBSCAN
from sklearn.neighbors import NearestNeighbors
from sklearn import preprocessing

# %% [markdown]
# #### Loading the kaggle Fake news dataset

# %%
df_fakenews=pd.read_csv("../data/train.csv")
df_fakenews.head(10)
# Out:
#    id                                              title  \
# 0   0  House Dem Aide: We Didn’t Even See Comey’s Let...
# 1   1  FLYNN: Hillary Clinton, Big Woman on Campus - ...
# 2   2                  Why the Truth Might Get You Fired
# 3   3  15 Civilians Killed In Single US Airstrike Hav...
# 4   4  Iranian woman jailed for fictional unpublished...
# 5   5  Jackie Mason: Hollywood Would Love Trump if He...
# 6   6  Life: Life Of Luxury: Elton John’s 6 Favorite ...
# 7   7  Benoît Hamon Wins French Socialist Party’s Pre...
# 8   8  Excerpts From a Draft Script for Donald Trump’...
# 9   9  A Back-Channel Plan for Ukraine and Russia, Co...
#
#                          author  \
# 0                 Darrell Lucus
# 1               Daniel J. Flynn
# 2            Consortiumnews.com
# 3               Jessica Purkiss
# 4                Howard Portnoy
# 5               Daniel Nussbaum
# 6                           NaN
# 7               Alissa J. Rubin
# 8                           NaN
# ...

# %%
df_fakenews=df_fakenews.dropna()

# %%
df_fakenews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18285 entries, 0 to 20799
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      18285 non-null  int64
#  1   title   18285 non-null  object
#  2   author  18285 non-null  object
#  3   text    18285 non-null  object
#  4   label   18285 non-null  int64
# dtypes: int64(2), object(3)
# memory usage: 857.1+ KB

# %% [markdown]
# #### Loading the features extracted  from kaggle fake news dataset

# %%
df_metadata=pd.read_csv("../data/kaggle_features/kaggle_features1.csv")
df_metadata
# Out:
#           id  n_tokens_title  n_tokens_content  n_unique_tokens  \
# 0          0        2.833213          6.742881         0.426887
# 1          1        2.197225          6.561031         0.521924
# 2          2        2.079442          7.150701         0.443922
# 3          3        2.397895          6.331502         0.444840
# 4          4        2.708050          5.030438         0.640523
# ...      ...             ...               ...              ...
# 18280  20795        2.397895          5.739793         0.601286
# 18281  20796        2.564949          7.024649         0.349644
# 18282  20797        2.833213          6.723832         0.462740
# 18283  20798        2.197225          5.620401         0.590580
# 18284  20799        1.945910          7.075809         0.487743
#
#        n_non_stop_words  n_non_stop_unique_tokens  average_token_length  \
# 0              0.520047                  0.338443              8.289037
# ...

# %% [markdown]
# ## K-Means clustering

# %%
df_metadata.describe()
# Out:
#                  id  n_tokens_title  n_tokens_content  n_unique_tokens  \
# count  18285.000000    18285.000000      18285.000000     18285.000000
# mean   10409.807383        2.548326          6.247553         0.516850
# std     5998.216236        0.344879          1.122977         0.130861
# min        0.000000        0.000000          0.000000         0.000000
# 25%     5217.000000        2.397895          5.730100         0.433414
# 50%    10422.000000        2.639057          6.429719         0.493671
# 75%    15603.000000        2.772589          7.005789         0.575439
# max    20799.000000        4.248495         10.119647         1.000000
#
#        n_non_stop_words  n_non_stop_unique_tokens  average_token_length  \
# count      18285.000000              18285.000000          18211.000000
# mean           0.571081                  0.403252              7.823621
# std            0.080440                  0.087965              1.051599
# ...

# %% [markdown]
# #### considering five features from the metadata dataset based on the highest std values

# %%
df_metadata_cluster=df_metadata.loc[:,['n_tokens_content','average_token_length','max_positive_polarity','max_negative_polarity','title_subjectivity']]

# %%
df_metadata_cluster.head()
# Out:
#    n_tokens_content  average_token_length  max_positive_polarity  \
# 0          6.742881              8.289037                   0.70
# 1          6.561031              8.106515                   0.80
# 2          7.150701              8.728426                   0.60
# 3          6.331502              7.864804                   0.55
# 4          5.030438              6.626718                   0.00
#
#    max_negative_polarity  title_subjectivity
# 0              -1.000000            0.000000
# 1              -0.666667            0.100000
# 2              -0.700000            0.000000
# 3              -0.300000            0.107143
# 4              -0.050000            0.250000

# %% [markdown]
# #### getting rid of null values from metadata dataset

# %%
df_metadata_cluster.fillna(0, inplace=True)

# %% [markdown]
# ### Elbow Method for optimal value of k in KMeans

# %% [markdown]
# #### The Elbow Method is one of the most popular methods to determine this optimal value of k.

# %%
K = df_metadata_cluster
K = K.iloc[:,[0,1,2, 3,4]].values
from sklearn.cluster import KMeans
wcss =[]
for j in range (1,20):
    kmeans = KMeans(n_clusters = j, init = 'k-means++', max_iter =100, n_init = 10, random_state = 0)
    kmeans.fit(K)
    wcss.append(kmeans.inertia_)
plt.figure(figsize=(15,10))
plt.plot(range(1,20),wcss)
plt.title('Elbow Method')
plt.xlabel('No of clusters')
plt.ylabel('WCSS')
plt.grid()
plt.show()

# %% [markdown]
# #### The knee (or elbow) point is calculated simply by instantiating the KneeLocator class with x, y and the appropriate curve and direction. Here, kneedle.knee and/or kneedle.elbow store the point of maximum curvature.

# %%
from kneed import KneeLocator
kn = KneeLocator(range(1,20), wcss, curve='convex', direction='decreasing')
elbow_k=kn.knee
print(elbow_k)
# Out:
# 4

# %%
kmeans = KMeans(n_clusters=elbow_k , init = 'k-means++', max_iter = 1000, n_init = 10, random_state = 0)
Kmeans = kmeans.fit_predict(K)
df_metadata_cluster["Kmean_Clusters"] = Kmeans

# %%
Kmeans
# Out:
# array([2, 3, 2, ..., 2, 0, 2], dtype=int32)

# %%
cluster1 = cluster2 = cluster0 = cluster3  = 0

for row in df_metadata_cluster["Kmean_Clusters"]:
    if row == 1:
        cluster1 = cluster1 + 1
    elif row == 2:
        cluster2 = cluster2 + 1
    elif row==3:
        cluster3 = cluster3 + 1
    else:
        cluster0 = cluster0 + 1
print(cluster2)
Cluster = [ cluster1, cluster2,cluster3, cluster0]
# Out:
# 7220

# %%
df_metadata_cluster.head()
# Out:
#    n_tokens_content  average_token_length  max_positive_polarity  \
# 0          6.742881              8.289037                   0.70
# 1          6.561031              8.106515                   0.80
# 2          7.150701              8.728426                   0.60
# 3          6.331502              7.864804                   0.55
# 4          5.030438              6.626718                   0.00
#
#    max_negative_polarity  title_subjectivity  Kmean_Clusters
# 0              -1.000000            0.000000               2
# 1              -0.666667            0.100000               3
# 2              -0.700000            0.000000               2
# 3              -0.300000            0.107143               3
# 4              -0.050000            0.250000               0

# %%
plt.figure(figsize=(8,8))
df_metadata_cluster["Kmean_Clusters"].value_counts().plot.pie(autopct = "%2.0f%%",
                                             colors =sns.color_palette("rainbow",5),
                                             wedgeprops = {"linewidth":5,"edgecolor":"white"})
my_circ = plt.Circle((0,0),0,color = "red")
plt.gca().add_artist(my_circ)
plt.title("PROPORTION OF Clusters")
plt.show()

# %% [markdown]
# #### As we can see from above pie chart, our dataset has been categorized into 4 clusters

# %% [markdown]
# ## predicting which cluster does the data comes in

# %% [markdown]
# #### Here we are predicting which cluster the news article goes

# %%
predicted_cluster=kmeans.predict([K[10100]])
print(predicted_cluster)
# Out:
# [2]

# %%
len(df_fakenews)
# Out:
# 18285

# %%
dataset_cluster=df_fakenews[kmeans.labels_==predicted_cluster.squeeze()]

# %% [markdown]
# #### Here we are recommending the related news articles from  cluster predicted above

# %%
dataset_cluster.reset_index(inplace=True)
ind = np.where((dataset_cluster['label'] == 0))[0].tolist()

dataset1 = dataset_cluster.loc[ind,['id','author','title']]

# %%
dataset1.sample(5)
# Out:
#          id                             author  \
# 2802   8106  Karen Zraick and Sandra Stevenson
# 2102   6056                       John Hayward
# 5667  16283                       John Hayward
# 7215  20785                        Ann Coulter
# 7006  20185                          Nate Cohn
#
#                                                   title
# 2802  Trump, Price, Pruitt: Your Wednesday Evening B...
# 2102  Trump Agenda on Offense: 7 Stories in 24 Hours...
# 5667  Study: Unemployment Fuels National Drug Epidem...
# 7215  Ann Coulter: How to Provide Universal Health C...
# 7006  Is Traditional Polling Underselling Donald Tru...

# %% [markdown]
# #### calculating how many datapoints are present in each cluster

# %%
df_metadata_cluster.groupby(['Kmean_Clusters'])['n_tokens_content'].count()
# Out:
# Kmean_Clusters
# 0    3529
# 1     741
# 2    7220
# 3    6795
# Name: n_tokens_content, dtype: int64

# %%
kmeans = KMeans(n_clusters=elbow_k)
clusteredData = kmeans.fit_predict(df_metadata_cluster)
for index in range(df_metadata_cluster.shape[1]):
    column = df_metadata_cluster.iloc[: , index]
    plt.scatter(column,clusteredData, c= clusteredData, alpha=0.25) 
    plt.xlabel(df_metadata_cluster.columns[index])
    plt.ylabel('clusters')
    plt.show()
